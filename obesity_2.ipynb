# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\Intellipaat\kegal datasets\playground-series-s4e2\train.csv")
data
# Out:
#           id  Gender        Age    Height      Weight  \
# 0          0    Male  24.443011  1.699998   81.669950
# 1          1  Female  18.000000  1.560000   57.000000
# 2          2  Female  18.000000  1.711460   50.165754
# 3          3  Female  20.952737  1.710730  131.274851
# 4          4    Male  31.641081  1.914186   93.798055
# ...      ...     ...        ...       ...         ...
# 20753  20753    Male  25.137087  1.766626  114.187096
# 20754  20754    Male  18.000000  1.710000   50.000000
# 20755  20755    Male  20.101026  1.819557  105.580491
# 20756  20756    Male  33.852953  1.700000   83.520113
# 20757  20757    Male  26.680376  1.816547  118.134898
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# 2                                yes  yes  1.880534  1.411685   Sometimes
# ...

# %%
data_1 = pd.read_csv(r"D:\Downloads\archive (2)\ObesityDataSet.csv")
data_1
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df = pd.concat([data,data_1],axis = 0)
df.reset_index(drop= True,inplace=True)
df
# Out:
#         id  Gender        Age    Height      Weight  \
# 0      0.0    Male  24.443011  1.699998   81.669950
# 1      1.0  Female  18.000000  1.560000   57.000000
# 2      2.0  Female  18.000000  1.711460   50.165754
# 3      3.0  Female  20.952737  1.710730  131.274851
# 4      4.0    Male  31.641081  1.914186   93.798055
# ...    ...     ...        ...       ...         ...
# 22864  NaN  Female  20.976842  1.710730  131.408528
# 22865  NaN  Female  21.982942  1.748584  133.742943
# 22866  NaN  Female  22.524036  1.752206  133.689352
# 22867  NaN  Female  24.361936  1.739450  133.346641
# 22868  NaN  Female  23.664709  1.738836  133.472641
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# 2                                yes  yes  1.880534  1.411685   Sometimes
# ...

# %%
import pandas as pd

# Sample DataFrame
data['NObeyesdad'] = {
    'Category_Column': ['Overweight_Level_II', 'Normal_Weight', 'Insufficient_Weight', 
                        'Obesity_Type_III', 'Obesity_Type_II', 'Overweight_Level_I', 'Obesity_Type_I']
}

df = pd.DataFrame(data['NObeyesdad'])

# Mapping dictionary for categorical to numerical values
mapping_dict = {
    'Overweight_Level_II': 2,
    'Normal_Weight': 0,
    'Insufficient_Weight': 6,
    'Obesity_Type_III': 5,
    'Obesity_Type_II': 4,
    'Overweight_Level_I': 1,
    'Obesity_Type_I': 3
}

# Replace the entire column with numerical values
df['NObeyesdad'] = df['NObeyesdad'].map(mapping_dict)

# Print the modified DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df
# Out:
#         id  Gender        Age    Height      Weight  \
# 0      0.0    Male  24.443011  1.699998   81.669950
# 1      1.0  Female  18.000000  1.560000   57.000000
# 2      2.0  Female  18.000000  1.711460   50.165754
# 3      3.0  Female  20.952737  1.710730  131.274851
# 4      4.0    Male  31.641081  1.914186   93.798055
# ...    ...     ...        ...       ...         ...
# 22864  NaN  Female  20.976842  1.710730  131.408528
# 22865  NaN  Female  21.982942  1.748584  133.742943
# 22866  NaN  Female  22.524036  1.752206  133.689352
# 22867  NaN  Female  24.361936  1.739450  133.346641
# 22868  NaN  Female  23.664709  1.738836  133.472641
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# 2                                yes  yes  1.880534  1.411685   Sometimes
# ...

# %%
df['data_2'].unique
# Out:
# <bound method Series.unique of 0        Overweight_Level_II
# 1              Normal_Weight
# 2        Insufficient_Weight
# 3           Obesity_Type_III
# 4            Obesity_Type_II
#                 ...
# 22864                    NaN
# 22865                    NaN
# 22866                    NaN
# 22867                    NaN
# 22868                    NaN
# Name: data_2, Length: 22869, dtype: object>

# %%
df['NObeyesdad'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22869 entries, 0 to 22868
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  float64
#  1   Gender                          22869 non-null  object
#  2   Age                             22869 non-null  float64
#  3   Height                          22869 non-null  float64
#  4   Weight                          22869 non-null  float64
#  5   family_history_with_overweight  22869 non-null  object
#  6   FAVC                            22869 non-null  object
#  7   FCVC                            22869 non-null  float64
#  8   NCP                             22869 non-null  float64
#  9   CAEC                            22869 non-null  object
#  10  SMOKE                           22869 non-null  object
#  11  CH2O                            22869 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# id                                2111
# Gender                               0
# Age                                  0
# Height                               0
# Weight                               0
# family_history_with_overweight       0
# FAVC                                 0
# FCVC                                 0
# NCP                                  0
# CAEC                                 0
# SMOKE                                0
# CH2O                                 0
# SCC                                  0
# FAF                                  0
# TUE                                  0
# CALC                                 0
# MTRANS                               0
# NObeyesdad                           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#             id  Gender        Age    Height      Weight  \
# 0          0.0    Male  24.443011  1.699998   81.669950
# 1          1.0  Female  18.000000  1.560000   57.000000
# 2          2.0  Female  18.000000  1.711460   50.165754
# 3          3.0  Female  20.952737  1.710730  131.274851
# 4          4.0    Male  31.641081  1.914186   93.798055
# ...        ...     ...        ...       ...         ...
# 20753  20753.0    Male  25.137087  1.766626  114.187096
# 20754  20754.0    Male  18.000000  1.710000   50.000000
# 20755  20755.0    Male  20.101026  1.819557  105.580491
# 20756  20756.0    Male  33.852953  1.700000   83.520113
# 20757  20757.0    Male  26.680376  1.816547  118.134898
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
ohe = OneHotEncoder(sparse_output= False)
ohe
# Out:
# OneHotEncoder(sparse_output=False)

# %%
df['Gender'] = ohe.fit_transform(df['Gender'].values.reshape(-1,1))
df['family_history_with_overweight'] = ohe.fit_transform(df['family_history_with_overweight'].values.reshape(-1,1))
df['FAVC'] = ohe.fit_transform(df['FAVC'].values.reshape(-1,1))
df['CAEC'] = ohe.fit_transform(df['CAEC'].values.reshape(-1,1))
df['SMOKE'] = ohe.fit_transform(df['SMOKE'].values.reshape(-1,1))
df['SCC'] = ohe.fit_transform(df['SCC'].values.reshape(-1,1))
df['CALC'] = ohe.fit_transform(df['CALC'].values.reshape(-1,1))
df['MTRANS'] = ohe.fit_transform(df['MTRANS'].values.reshape(-1,1))
# df['NObeyesdad'] = ohe.fit_transform(df['NObeyesdad'].values.reshape(-1,1))

# %%
df
# Out:
#             id  Gender        Age    Height      Weight  \
# 0          0.0     0.0  24.443011  1.699998   81.669950
# 1          1.0     1.0  18.000000  1.560000   57.000000
# 2          2.0     1.0  18.000000  1.711460   50.165754
# 3          3.0     1.0  20.952737  1.710730  131.274851
# 4          4.0     0.0  31.641081  1.914186   93.798055
# ...        ...     ...        ...       ...         ...
# 20753  20753.0     0.0  25.137087  1.766626  114.187096
# 20754  20754.0     0.0  18.000000  1.710000   50.000000
# 20755  20755.0     0.0  20.101026  1.819557  105.580491
# 20756  20756.0     0.0  33.852953  1.700000   83.520113
# 20757  20757.0     0.0  26.680376  1.816547  118.134898
#
#        family_history_with_overweight  FAVC      FCVC       NCP  CAEC  SMOKE  \
# 0                                 0.0   0.0  2.000000  2.983297   0.0    1.0
# 1                                 0.0   0.0  2.000000  3.000000   0.0    1.0
# ...

# %%
x_train = df.iloc[:,:-1]
x_train
# Out:
#             id  Gender        Age    Height      Weight  \
# 0          0.0     0.0  24.443011  1.699998   81.669950
# 1          1.0     1.0  18.000000  1.560000   57.000000
# 2          2.0     1.0  18.000000  1.711460   50.165754
# 3          3.0     1.0  20.952737  1.710730  131.274851
# 4          4.0     0.0  31.641081  1.914186   93.798055
# ...        ...     ...        ...       ...         ...
# 20753  20753.0     0.0  25.137087  1.766626  114.187096
# 20754  20754.0     0.0  18.000000  1.710000   50.000000
# 20755  20755.0     0.0  20.101026  1.819557  105.580491
# 20756  20756.0     0.0  33.852953  1.700000   83.520113
# 20757  20757.0     0.0  26.680376  1.816547  118.134898
#
#        family_history_with_overweight  FAVC      FCVC       NCP  CAEC  SMOKE  \
# 0                                 0.0   0.0  2.000000  2.983297   0.0    1.0
# 1                                 0.0   0.0  2.000000  3.000000   0.0    1.0
# ...

# %%
y_train = df.iloc[:,-1:]
y_train
# Out:
#                 NObeyesdad
# 0      Overweight_Level_II
# 1            Normal_Weight
# 2      Insufficient_Weight
# 3         Obesity_Type_III
# 4      Overweight_Level_II
# ...                    ...
# 20753      Obesity_Type_II
# 20754  Insufficient_Weight
# 20755      Obesity_Type_II
# 20756  Overweight_Level_II
# 20757      Obesity_Type_II
#
# [20758 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_train,y_train,test_size=0.2,random_state= 42)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ad = AdaBoostClassifier()
ad
# Out:
# AdaBoostClassifier()

# %%
ad.fit(x_train,y_train)
# Out:
# C:\Users\mahes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mahes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
y_pred = ad.predict(x_test)
y_pred
# Out:
# array(['Obesity_Type_II', 'Overweight_Level_II', 'Overweight_Level_II',
#        ..., 'Overweight_Level_II', 'Overweight_Level_II',
#        'Overweight_Level_II'], dtype=object)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4328034682080925

# %%
test = pd.read_csv(r"D:\Intellipaat\kegal datasets\playground-series-s4e2\test.csv")
test
# Out:
#           id  Gender        Age    Height      Weight  \
# 0      20758    Male  26.899886  1.848294  120.644178
# 1      20759  Female  21.000000  1.600000   66.000000
# 2      20760  Female  26.000000  1.643355  111.600553
# 3      20761    Male  20.979254  1.553127  103.669116
# 4      20762  Female  26.000000  1.627396  104.835346
# ...      ...     ...        ...       ...         ...
# 13835  34593    Male  23.327836  1.721384   78.030383
# 13836  34594  Female  29.000000  1.590000   62.000000
# 13837  34595  Female  22.935612  1.585547   44.376637
# 13838  34596    Male  21.000000  1.620000   53.000000
# 13839  34597    Male  26.490926  1.812259  120.980508
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.938616  3.000000   Sometimes
# 1                                yes  yes  2.000000  1.000000   Sometimes
# 2                                yes  yes  3.000000  3.000000   Sometimes
# ...

# %%
test['Gender'] = ohe.fit_transform(test['Gender'].values.reshape(-1,1))
test['family_history_with_overweight'] = ohe.fit_transform(test['family_history_with_overweight'].values.reshape(-1,1))
test['FAVC'] = ohe.fit_transform(test['FAVC'].values.reshape(-1,1))
test['CAEC'] = ohe.fit_transform(test['CAEC'].values.reshape(-1,1))
test['SMOKE'] = ohe.fit_transform(test['SMOKE'].values.reshape(-1,1))
test['SCC'] = ohe.fit_transform(test['SCC'].values.reshape(-1,1))
test['CALC'] = ohe.fit_transform(test['CALC'].values.reshape(-1,1))
test['MTRANS'] = ohe.fit_transform(test['MTRANS'].values.reshape(-1,1))

# %%
test
# Out:
#           id  Gender        Age    Height      Weight  \
# 0      20758     0.0  26.899886  1.848294  120.644178
# 1      20759     1.0  21.000000  1.600000   66.000000
# 2      20760     1.0  26.000000  1.643355  111.600553
# 3      20761     0.0  20.979254  1.553127  103.669116
# 4      20762     1.0  26.000000  1.627396  104.835346
# ...      ...     ...        ...       ...         ...
# 13835  34593     0.0  23.327836  1.721384   78.030383
# 13836  34594     1.0  29.000000  1.590000   62.000000
# 13837  34595     1.0  22.935612  1.585547   44.376637
# 13838  34596     0.0  21.000000  1.620000   53.000000
# 13839  34597     0.0  26.490926  1.812259  120.980508
#
#        family_history_with_overweight  FAVC      FCVC       NCP  CAEC  SMOKE  \
# 0                                 0.0   0.0  2.938616  3.000000   0.0    1.0
# 1                                 0.0   0.0  2.000000  1.000000   0.0    1.0
# 2                                 0.0   0.0  3.000000  3.000000   0.0    1.0
# ...

# %%
pred = ad.predict(test)
pred
# Out:
# array(['Obesity_Type_II', 'Overweight_Level_I', 'Obesity_Type_II', ...,
#        'Normal_Weight', 'Normal_Weight', 'Obesity_Type_II'], dtype=object)

# %%
submission = pd.DataFrame({'id': test['id'],'NObeyesdad': pred})
submission
# Out:
#           id           NObeyesdad
# 0      20758      Obesity_Type_II
# 1      20759   Overweight_Level_I
# 2      20760      Obesity_Type_II
# 3      20761      Obesity_Type_II
# 4      20762      Obesity_Type_II
# ...      ...                  ...
# 13835  34593  Overweight_Level_II
# 13836  34594   Overweight_Level_I
# 13837  34595        Normal_Weight
# 13838  34596        Normal_Weight
# 13839  34597      Obesity_Type_II
#
# [13840 rows x 2 columns]

# %%
submission.to_csv('submission_1.csv',index = False)
